# %% [markdown]
# # 02 Feature Analysis
#
# This notebook analyzes feature distributions, collinearity, and feature usefulness under strict labels.

# %%
from pathlib import Path
import pandas as pd

ROOT = Path.cwd().parent
df = pd.read_csv(ROOT / 'training_data' / 'real_labeled_runs_strict_curated.csv')
meta_cols = {'sub_id','query_id','dataset','label','label_source'}
feature_cols = [c for c in df.columns if c not in meta_cols and not c.endswith('_ms') and not c.endswith('_std_ms')]
print('Feature count:', len(feature_cols))
print(feature_cols[:10])

# %%
# TODO: Add VIF computation and correlation heatmap.
# TODO: Add per-feature separation plots grouped by label.
