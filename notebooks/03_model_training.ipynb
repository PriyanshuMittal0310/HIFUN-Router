# %% [markdown]
# # 03 Model Training
#
# This notebook trains baseline and learned routers on strict train/eval splits and reports robust metrics.

# %%
from pathlib import Path
import pandas as pd

ROOT = Path.cwd().parent
train_df = pd.read_csv(ROOT / 'training_data' / 'fixed_train_base_strict.csv')
eval_df = pd.read_csv(ROOT / 'training_data' / 'fixed_eval_set_strict.csv')
print('Train:', train_df.shape, train_df['label'].value_counts().to_dict())
print('Eval :', eval_df.shape, eval_df['label'].value_counts().to_dict())

# %%
# TODO: Train TraversalRule, LogReg, DecisionTree, XGBoost and compare F1/PR-AUC/Brier.
# TODO: Add bootstrap confidence intervals for key metrics.
