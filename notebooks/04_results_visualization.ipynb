# %% [markdown]
# # 04 Results Visualization
#
# This notebook visualizes strict relevance, robustness, ablation, and dataset-shift artifacts for the report.

# %%
from pathlib import Path
import json

ROOT = Path.cwd().parent
results_dir = ROOT / 'experiments' / 'results'
print('Results files:', sorted([p.name for p in results_dir.glob('*strict*.md')])[:10])

# %%
# TODO: Plot model comparison bars from relevance_eval_strict.md.
# TODO: Plot CI intervals and transfer failures in one dashboard.
