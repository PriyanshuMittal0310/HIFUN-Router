# %% [markdown]
# # 01 Data Exploration
#
# This notebook documents dataset loading, schema checks, class balance, and split sanity checks.

# %%
from pathlib import Path
import pandas as pd

ROOT = Path.cwd().parent
DATA = ROOT / 'training_data'
STRICT = DATA / 'real_labeled_runs_strict_curated.csv'
print('Strict dataset exists:', STRICT.exists())
if STRICT.exists():
    df = pd.read_csv(STRICT)
    print(df.shape)
    print(df.columns.tolist()[:12])

# %%
# TODO: Add dataset-wise label distribution and missing-value profile.
# TODO: Add strict/eval split overlap audit and leakage checks.
